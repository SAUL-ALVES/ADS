# %%
def porteiro(nome):
  qtd_letras = len(nome)
  if qtd_letras < 6:
   comprimento = 'curto'
  else:
    comprimento = 'comprido'
  print(f'Olá, {nome}!')
  print(f'Seu nome é {comprimento}.')
  print('Boa continuação do de dia!')

porteiro('Saul')
s = input('Digite seu nome: ')
porteiro(s)
porteiro(s[:5][::-1])



def soma(a: int, b: int) -> int:
    return a + b

z = 4
s1 = soma(5, 1)
s2 = soma(90, -7)
s3 = soma(z * 2, - z)

print(f'A soma é {s1}.')
print(f'A soma é {s2}.')
print(f'A soma é {s3}.')

def mult_pot(a: int, b: int) -> int:
    return a ** b
r1 = mult_pot(2, 5)
r2 = mult_pot(-3, 2)

print(f'O resultado é {r1}.')
print(f'O resultado é {r2}.')

#Exercícios

#1

def ope(a: int, b: int):
  return a+b, a-b, a*b, a/b

ope(10, 2)

#3

def fun1(num):
  return num + 25
fun1(5)
print(num)

#retorna erro

#4
def conceito(media: float) -> str:
  if media < 5:
    return 'D'
  if media < 7:
    return 'C'
  if media < 9:
    return 'B'
return 'A'
print(conceito(9))

# %%
#5

def conversao(lista):
  return[0 if numeros < 0 else numeros for numeros in lista]
numeros = [-1, 2, 3, 4, -5]
print (conversao(numeros))


#6

def verify(numero):
  return numero >= 0
valor = int(input('Digite um número: '))
if verify(valor):
  print('O número é positivo.')
else:
  print('O número é negativo.')

#7

def contar(lista):
  imp = 0
  for i in lista:
    if i % 2 != 0:
      imp += 1
  return (lista, imp)
result = contar(numeros)
numeros = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print (f"A quantidade de números ímpares é: {result[1]}")
